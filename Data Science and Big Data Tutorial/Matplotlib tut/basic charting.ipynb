# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot([1,2,3],[5,15,17])
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot([1,2,3],[5,15,17])
plt.title("Huzefa's Data")
plt.xlabel('This is X')
plt.ylabel('This is Y')
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import style

style.use('ggplot')
x = [2,4,6]
y = [12,24,36]
x1 = [5,7,9]
y1 = [10,13,19]

plt.plot(x,y)
plt.plot(x1,y1)
plt.show()
